# %% [markdown]
# # Import dependencies

# %%
# import libraries
import numpy as numpy
import skimage
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# # Data processing

# %% [markdown]
# Q1.
# Define a matrix A =[[1 2 3], [4,5,6]]
# - Find, entire matrix, second row, third element of second row, last element of first row

# %% [markdown]
# Q2. Define two matrices of random integer B and C with dimension 3x3
# Perform dot procuct using - np.dot, np.matmul,  @

# %% [markdown]
# Q3. Solving system of linear equation.
# 5x_1 + 2x_2 = 33; x_1 + 4x_2 = 21;

# %% [markdown]
# Q4. Eigen values and Eigen vectors; Determinants
# Define a matrix [[1,3], [4,-3]]. Find Eigene value and Eigene vector; and determinant

# %% [markdown]
# Q5.
#
# data= read the file Heart Attack.csv
#
# X=data in all col except last
# y=last col
#
#
# X_norm=Normalize each column between 0 and 1 ((x-mean(x)/std(x))).  This translates data to mean 0 and variance 1
# plot data_norm in different subplot
#
# data_cov=covariance of data_norm
#
# dist_ij=find dot product of col i with all other col in X. Plot them. E.g. dist_1j=dot product of col 1 with others
#
# hist_i= choose a column in X_norm, plot the histogram, fit the data to Gaussian probability density function, find the parameters

# %% [markdown]
# # Image processing

# %% [markdown]
# Some standard functionalities in python
#
# np.array, np.zeros, np.ones, np.hstack, np.vstack, np.shape, np.full, cv2.imread, cv2.imwrite, io.imread, io.imshow, filters.sobel, filters.gaussian, cv2.filter2D, np.linspace, np.outer, cv2.blur, cv2.calcHist, np.histogram, np.fft.fft2, np.fft.fftshift, np.arctan2

# %% [markdown]
# Q6. Convert numpy array to image
#
# - Create a ones vector of dimension 100x1 and name it a
#
# - Similarly b is zeros vector of dimension 100x1
#
# - Concatenate it horizontally; find its dimension
#
# - Concatenate it vertically; find its dimension
#
# - Convert to image (in variable img), find its dimension
#
# - Save it in local drive and read it again
#
# - Find the dimension of img; print the value of pixel value in (100,50)

# %% [markdown]
# Q7. Edge detection
#
# - Read practice_raw_image.png as colour (name it - img_leaf), and gray scale (name it - img_leaf_grey). Plot them side by side with proper xlabel, ylabel and title
#
# - Find the edges of img_leaf_grey  using Sobel filter. (a) using standard libary (b) using kernel and coding yourself. Plot them side by side with proper xlabel, ylabel and title

# %% [markdown]
# Q8. Image filtering
#
# - Smooth the img_leaf_grey using (a)  Gaussian filter from standard library (b) using Gaussian kernel and coding yourself. Plot them side by side with proper xlabel, ylabel and title
#
# - (a) Read practice_raw_image.png (image_leaf_grey) (b) Generate noise :  a vector (n) whose size is equal to the size of image_leaf_grey and each element is sampled from  Gaussian distribution with mean=0 and variance=2 (c) add noise (n) to image_leaf_grey and name it image_leaf_grey_noise (d) use Gaussian filtering function from python to filter image_leaf_grey_noise (e) plot a-d using subplot with proper xlabel, ylabel and titles

# %% [markdown]
# Q9. Fourier transformation
#
# - (a) Generate a sine wave of frequency 100 Hz and amplitude 5V. (b) Find its Fourier transformation. Plot a and b with propoer label and title.
#
# - (a) Generate a signal that is sum of sine wave of amplitude 1 V and 100 Hz, and 2 V and 200 Hz. (b) Find its Fourier transformation.  Plot a and b with propoer label and title.
#
# - Find the Fourier transformation of image_leaf_grey. Plot magnitue and angle spectrum
#
# - Find the (a) low pass filtered image of image_leaf_grey. Plot the (a) original image, (b) magnitude spectrum (c) mask (d) masked image of 2D FFT (e) low pass filtered image with proper title and labels.
#
# - (b) Find the (a) high pass filtered image of image_leaf_grey. Plot the (a) original image, (b) magnitude spectrum (c) mask (d) masked image of 2D FFT (e) high pass filtered image with proper title and labels.

# %% [markdown]
# Q.10 Optical Flow algorithm is used to find the relative displacement of pixels from given image frames. 20250828_130534.mp4 contains a video of swinging load at given motion of stewart platform. Use optical flow algorithm to find the relative displacement of pixels representing swinging load. Use minimum five frames for your algorithm.
